# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Path to the input image
image_path = "/work/hdd/bczm/sjafarisheshtamad/COMS571/IDCIA v2/images/220815_GFP-AHPC_B_MAP2ab_F1_DAPI_ND1_20x.tiff"  # Replace with your image path

# Load the image
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB for displaying with matplotlib

# Sharpening kernel
sharpening_kernel = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])

# Apply sharpening filter
sharpened = cv2.filter2D(img, -1, sharpening_kernel)

# Apply deblurring (Gaussian blur)
deblurred = cv2.GaussianBlur(img, (0, 0), 3)

# Combine sharpening and deblurring
combined = cv2.addWeighted(sharpened, 3, deblurred, -1, 0)

# Display the original and filtered images
titles = ['Original Image', 'Sharpened Image', 'Deblurred Image', 'Combined Filters']
images = [img, sharpened, deblurred, combined]

plt.figure(figsize=(12, 8))
for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# Out:
# '/work/hdd/bczm/sjafarisheshtamad/COMS571'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Path to the blurred image
image_path = "/work/hdd/bczm/sjafarisheshtamad/COMS571/IDCIA v2/images/220815_GFP-AHPC_A_MAP2ab_F1_DAPI_ND1_20x.tiff"  # Replace with your image path

# Load the blurred image
blurred_img = cv2.imread(image_path)
blurred_img = cv2.cvtColor(blurred_img, cv2.COLOR_BGR2RGB)

# Sharpening kernel to reduce blur
sharpening_kernel = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])

# Apply sharpening filter
deblurred_img = cv2.filter2D(blurred_img, -1, sharpening_kernel)

# Display the original blurred and deblurred images
titles = ['Blurred Image', 'Deblurred Image']
images = [blurred_img, deblurred_img]

plt.figure(figsize=(10, 5))
for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Path to the input image
image_path = "/work/hdd/bczm/sjafarisheshtamad/COMS571/IDCIA v2/images/220815_GFP-AHPC_A_MAP2ab_F1_DAPI_ND1_20x.tiff"  # Replace with your image path

# Load the image
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB for displaying with matplotlib

# Sharpening kernel
sharpening_kernel = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])

# Apply sharpening filter
sharpened = cv2.filter2D(img, -1, sharpening_kernel)

# Increase brightness by adding a scalar value
brightness_increase = 50  # Adjust this value as needed
brighter_and_sharper = cv2.add(sharpened, np.array([brightness_increase], dtype=np.uint8))

# Display the original and enhanced images
titles = ['Original Image', 'Sharpened and Brighter Image']
images = [img, brighter_and_sharper]

plt.figure(figsize=(10, 5))
for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 22
#      20 # Increase brightness by adding a scalar value
#      21 brightness_increase = 50  # Adjust this value as needed
# ---> 22 brighter_and_sharper = cv2.add(sharpened, np.array([brightness_increase], dtype=np.uint8))
#      24 # Display the original and enhanced images
#      25 titles = ['Original Image', 'Sharpened and Brighter Image']
#
# error: OpenCV(4.8.0) /io/opencv/modules/core/src/arithm.cpp:652: error: (-215:Assertion failed) type2 == CV_64F && (sz2.height == 1 || sz2.height == 4) in function 'arithm_op'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Path to the input image
image_path = "/work/hdd/bczm/sjafarisheshtamad/COMS571/IDCIA v2/images/220815_GFP-AHPC_A_MAP2ab_F1_DAPI_ND1_20x.tiff"  # Replace with your image path

# Load the image
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB for displaying with matplotlib

# Sharpening kernel
sharpening_kernel = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])

# Apply sharpening filter
sharpened = cv2.filter2D(img, -1, sharpening_kernel)

# Increase brightness by adding a scalar value
brightness_increase = 50  # Adjust this value as needed
brighter_and_sharper = cv2.add(sharpened, np.full(sharpened.shape, brightness_increase, dtype=np.uint8))

# Display the original and enhanced images
titles = ['Original Image', 'Sharpened and Brighter Image']
images = [img, brighter_and_sharper]

plt.figure(figsize=(10, 5))
for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()
